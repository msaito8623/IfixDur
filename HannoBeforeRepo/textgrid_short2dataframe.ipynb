# %%
# textgrid_short2dataframe
# H. Muller
# 2023-08-04

# %% [markdown]
# # Define functions

# %%
import tgt

# open file
def inputtextlines(filename):
    textgrid_short = tgt.io.read_textgrid(filename, encoding='latin-1', include_empty_intervals=True)
    textgrid_long = tgt.io.export_to_long_textgrid(textgrid_short)
    linelist = textgrid_long.split('\n')
    return(linelist)

# %%
# Conversion routines
def converttextgrid2list(textgridlines,textgridname):

    data = []

    newtier = False
    for line in textgridlines[9:]:
        line = re.sub('\n','',line)
        line = re.sub('\t','',line)
        line = re.sub('^ *','',line)
        linepair = line.split(' = ')
        if len(linepair) == 2:
            if linepair[0] == 'class':
                classname = linepair[1].strip().strip('\"')
            if linepair[0] == 'name':
                tiername = linepair[1].strip().strip('\"')
            if linepair[0] == 'xmin':
                xmin = float(linepair[1])
            if linepair[0] == 'xmax':
                xmax = float(linepair[1])
            if linepair[0] == 'text':
                text = linepair[1].strip().strip('\"')
                diff = xmax-xmin
                data.append([textgridname, classname, tiername, text, xmin, xmax, diff])
                
    return(data)

# %% [markdown]
# # Load modules and data

# %%
import sys, re, os
import pandas as pd

# %%
# Parse arguments
if os.environ.get('inputfiles'):
    inputPath = os.environ.get('inputfiles')
else:
    inputPath = '../DataProcessed/CGN_alignment_comp-o_nl/'
    
if os.environ.get('outputpath'):
    outputPath = os.environ.get('outputpath')
else:
    outputPath = '../DataProcessed/cgn_alignments_comp-o_nl.pkl'

# %%
# get all files
onlyfiles = [os.path.join(inputPath,f) for f in os.listdir(inputPath) if os.path.isfile(os.path.join(inputPath, f))]
onlyfiles[:10]
# Out:
# ['../DataProcessed/CGN_alignment_comp-o_nl/fn001092.awd',
#  '../DataProcessed/CGN_alignment_comp-o_nl/fn001093.awd',
#  '../DataProcessed/CGN_alignment_comp-o_nl/fn001094.awd',
#  '../DataProcessed/CGN_alignment_comp-o_nl/fn001095.awd',
#  '../DataProcessed/CGN_alignment_comp-o_nl/fn001096.awd',
#  '../DataProcessed/CGN_alignment_comp-o_nl/fn001097.awd',
#  '../DataProcessed/CGN_alignment_comp-o_nl/fn001098.awd',
#  '../DataProcessed/CGN_alignment_comp-o_nl/fn001099.awd',
#  '../DataProcessed/CGN_alignment_comp-o_nl/fn001100.awd',
#  '../DataProcessed/CGN_alignment_comp-o_nl/fn001101.awd']

# %%
# set run to True to use subset for faster development
RUN=False
if RUN==True:
    onlyfiles = onlyfiles[:5]

# %% [markdown]
# # Parse textgrids

# %%
data = []
for filePath in onlyfiles:
    
    fileName = os.path.split(filePath)[1]
    textgrid = inputtextlines(filePath)
    data.extend(converttextgrid2list(textgrid, fileName))

df = pd.DataFrame(data, columns =['FileName', 'TierType', 'TierName', 'Label', 'Start', 'End', 'Duration'])
df['FileNameTierName'] = df.FileName + df.TierName
display(df.head())
display(df.tail())
# Out:
#        FileName      TierType TierName     Label  Start    End  Duration  \
# 0  fn001092.awd  IntervalTier   N00551            0.000  0.922     0.922
# 1  fn001092.awd  IntervalTier   N00551        ik  0.922  1.087     0.165
# 2  fn001092.awd  IntervalTier   N00551  vertelde  1.087  1.529     0.442
# 3  fn001092.awd  IntervalTier   N00551    meneer  1.529  1.786     0.257
# 4  fn001092.awd  IntervalTier   N00551      Wild  1.786  2.125     0.339
#
#      FileNameTierName
# 0  fn001092.awdN00551
# 1  fn001092.awdN00551
# 2  fn001092.awdN00551
# 3  fn001092.awdN00551
# 4  fn001092.awdN00551
#              FileName      TierType    TierName Label    Start      End  \
# 3647892  fn001091.awd  IntervalTier  N00551_SEG     l  231.015  231.086
# 3647893  fn001091.awd  IntervalTier  N00551_SEG    E+  231.086  231.238
# 3647894  fn001091.awd  IntervalTier  N00551_SEG     k  231.238  231.339
# 3647895  fn001091.awd  IntervalTier  N00551_SEG     @  231.339  231.399
# 3647896  fn001091.awd  IntervalTier  N00551_SEG        231.399  231.500
#
#          Duration        FileNameTierName
# 3647892     0.071  fn001091.awdN00551_SEG
# 3647893     0.152  fn001091.awdN00551_SEG
# 3647894     0.101  fn001091.awdN00551_SEG
# 3647895     0.060  fn001091.awdN00551_SEG
# 3647896     0.101  fn001091.awdN00551_SEG

# %%
# extract relevant tiernames
fileTierNames = df.FileNameTierName.drop_duplicates().to_list()
fileTierNames = [fileTier for fileTier in fileTierNames if "_" not in fileTier]
fileTierNames[:10]
# Out:
# ['fn001092.awdN00551',
#  'fn001093.awdN00552',
#  'fn001094.awdN00552',
#  'fn001095.awdN00554',
#  'fn001096.awdN00554',
#  'fn001097.awdN00555',
#  'fn001098.awdN00555',
#  'fn001099.awdN00557',
#  'fn001100.awdN00557',
#  'fn001101.awdN00558']

# %%
# set up list to store results and index to iterate through labels
data = []

# for each tier
for fileTier in fileTierNames:
    labelIndex = 1
    dfLabel = df.loc[df.FileNameTierName==fileTier,]
    dfFon = df.loc[df.FileNameTierName==fileTier+'_FON',]
    dfSeg = df.loc[df.FileNameTierName==fileTier+'_SEG',]
    
    # align segments to labels 
    for index, row in dfSeg.iterrows():
    
        # extract segment with start and end value
        Seg = row['Label']
        start = row['Start']
        end = row['End']
    
        # extract corresponding label (=word)
        label = dfLabel.iloc[labelIndex, dfLabel.columns.get_loc('Label')]
        trans = dfFon.iloc[labelIndex, dfFon.columns.get_loc('Label')]
        labelStart = dfLabel.iloc[labelIndex, dfLabel.columns.get_loc('Start')]
        labelEnd = dfLabel.iloc[labelIndex, dfLabel.columns.get_loc('End')]
        ID = str(labelIndex) + '-' + label
    
        # append everything to list
        data.append([fileTier, ID, label, labelStart, labelEnd, trans, Seg, start, end])
    
        # check if segment matches last segment of label or
        # is smaller (CGN does not perfectly align word boundaries with phone boundaries)
        if labelEnd <= end:
            labelIndex += 1
    
results = pd.DataFrame(data, columns =['FileNameTierName', 'ID', 'WordOrtho', 'WordStart', 'WordEnd', 'WordPhono', 'Phone', 
                    'PhoneStart', 'PhoneEnd',])
results[:20]
# Out:
#       FileNameTierName          ID WordOrtho  WordStart  WordEnd WordPhono  \
# 0   fn001092.awdN00551        1-ik        ik      0.922    1.087        Ik
# 1   fn001092.awdN00551        1-ik        ik      0.922    1.087        Ik
# 2   fn001092.awdN00551        1-ik        ik      0.922    1.087        Ik
# 3   fn001092.awdN00551  2-vertelde  vertelde      1.087    1.529  f@rtEld@
# 4   fn001092.awdN00551  2-vertelde  vertelde      1.087    1.529  f@rtEld@
# 5   fn001092.awdN00551  2-vertelde  vertelde      1.087    1.529  f@rtEld@
# 6   fn001092.awdN00551  2-vertelde  vertelde      1.087    1.529  f@rtEld@
# 7   fn001092.awdN00551  2-vertelde  vertelde      1.087    1.529  f@rtEld@
# 8   fn001092.awdN00551  2-vertelde  vertelde      1.087    1.529  f@rtEld@
# 9   fn001092.awdN00551  2-vertelde  vertelde      1.087    1.529  f@rtEld@
# 10  fn001092.awdN00551  2-vertelde  vertelde      1.087    1.529  f@rtEld@
# 11  fn001092.awdN00551    3-meneer    meneer      1.529    1.786     m@ner
# 12  fn001092.awdN00551    3-meneer    meneer      1.529    1.786     m@ner
# 13  fn001092.awdN00551    3-meneer    meneer      1.529    1.786     m@ner
# 14  fn001092.awdN00551    3-meneer    meneer      1.529    1.786     m@ner
# 15  fn001092.awdN00551    3-meneer    meneer      1.529    1.786     m@ner
# 16  fn001092.awdN00551      4-Wild      Wild      1.786    2.125      wIlt
# 17  fn001092.awdN00551      4-Wild      Wild      1.786    2.125      wIlt
# 18  fn001092.awdN00551      4-Wild      Wild      1.786    2.125      wIlt
# 19  fn001092.awdN00551      4-Wild      Wild      1.786    2.125      wIlt
#
#    Phone  PhoneStart  PhoneEnd
# 0              0.000     0.922
# 1      I       0.922     1.025
# 2      k       1.025     1.087
# 3      f       1.087     1.138
# 4      @       1.138     1.200
# 5      r       1.200     1.230
# 6      t       1.230     1.302
# 7      E       1.302     1.395
# 8      l       1.395     1.436
# 9      d       1.436     1.477
# 10     @       1.477     1.529
# 11     m       1.529     1.590
# 12     @       1.590     1.621
# 13     n       1.621     1.673
# 14     e       1.673     1.734
# 15     r       1.734     1.786
# 16     w       1.786     1.913
# 17     I       1.913     1.974
# 18     l       1.974     2.064
# 19     t       2.064     2.125

# %%
results.loc[results.WordOrtho=='boodschappenlijstje', ]
# Out:
# Empty DataFrame
# Columns: [FileNameTierName, ID, WordOrtho, WordStart, WordEnd, WordPhono, Phone, PhoneStart, PhoneEnd]
# Index: []

# %%
results.to_pickle(outputPath)

# %% [markdown]
# Load results into environment with:
#
# `results = pd.read_pickle('../DataProcessed/cgn_alignments_dataframe.pkl')`
