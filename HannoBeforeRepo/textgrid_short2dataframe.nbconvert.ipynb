# %%
# textgrid_short2dataframe
# H. Muller
# 2023-08-04

# %% [markdown]
# # Define functions

# %%
import tgt

# open file
def inputtextlines(filename):
    textgrid_short = tgt.io.read_textgrid(filename, encoding='latin-1', include_empty_intervals=True)
    textgrid_long = tgt.io.export_to_long_textgrid(textgrid_short)
    linelist = textgrid_long.split('\n')
    return(linelist)

# %%
# Conversion routines
def converttextgrid2list(textgridlines,textgridname):

    data = []

    newtier = False
    for line in textgridlines[9:]:
        line = re.sub('\n','',line)
        line = re.sub('\t','',line)
        line = re.sub('^ *','',line)
        linepair = line.split(' = ')
        if len(linepair) == 2:
            if linepair[0] == 'class':
                classname = linepair[1].strip().strip('\"')
            if linepair[0] == 'name':
                tiername = linepair[1].strip().strip('\"')
            if linepair[0] == 'xmin':
                xmin = float(linepair[1])
            if linepair[0] == 'xmax':
                xmax = float(linepair[1])
            if linepair[0] == 'text':
                text = linepair[1].strip().strip('\"')
                diff = xmax-xmin
                data.append([textgridname, classname, tiername, text, xmin, xmax, diff])
                
    return(data)

# %% [markdown]
# # Load modules and data

# %%
import sys, re, os
import pandas as pd

# %%
# Parse arguments
if os.environ.get('inputfiles'):
    inputPath = os.environ.get('inputfiles')
else:
    inputPath = '../DataProcessed/CGN_alignment_comp-o_nl/'
    
if os.environ.get('outputpath'):
    outputPath = os.environ.get('outputpath')
else:
    outputPath = '../DataProcessed/cgn_alignments_comp-o_nl.pkl'

# %%
# get all files
onlyfiles = [os.path.join(inputPath,f) for f in os.listdir(inputPath) if os.path.isfile(os.path.join(inputPath, f))]
onlyfiles[:10]
# Out:
# ['../DataProcessed/CGN_alignment_comp-o_vl/fv800097.awd',
#  '../DataProcessed/CGN_alignment_comp-o_vl/fv800098.awd',
#  '../DataProcessed/CGN_alignment_comp-o_vl/fv800101.awd',
#  '../DataProcessed/CGN_alignment_comp-o_vl/fv800102.awd',
#  '../DataProcessed/CGN_alignment_comp-o_vl/fv800103.awd',
#  '../DataProcessed/CGN_alignment_comp-o_vl/fv800104.awd',
#  '../DataProcessed/CGN_alignment_comp-o_vl/fv800105.awd',
#  '../DataProcessed/CGN_alignment_comp-o_vl/fv800106.awd',
#  '../DataProcessed/CGN_alignment_comp-o_vl/fv800107.awd',
#  '../DataProcessed/CGN_alignment_comp-o_vl/fv800108.awd']

# %%
# set run to True to use subset for faster development
RUN=False
if RUN==True:
    onlyfiles = onlyfiles[:5]

# %% [markdown]
# # Parse textgrids

# %%
data = []
for filePath in onlyfiles:
    
    fileName = os.path.split(filePath)[1]
    textgrid = inputtextlines(filePath)
    data.extend(converttextgrid2list(textgrid, fileName))

df = pd.DataFrame(data, columns =['FileName', 'TierType', 'TierName', 'Label', 'Start', 'End', 'Duration'])
df['FileNameTierName'] = df.FileName + df.TierName
display(df.head())
display(df.tail())
# Out:
#        FileName      TierType TierName    Label  Start    End  Duration  \
# 0  fv800097.awd  IntervalTier   V80010           0.000  0.803     0.803
# 1  fv800097.awd  IntervalTier   V80010  Falcone  0.803  1.434     0.631
# 2  fv800097.awd  IntervalTier   V80010      was  1.434  1.631     0.197
# 3  fv800097.awd  IntervalTier   V80010     toen  1.631  1.825     0.194
# 4  fv800097.awd  IntervalTier   V80010      nog  1.825  2.007     0.182
#
#      FileNameTierName
# 0  fv800097.awdV80010
# 1  fv800097.awdV80010
# 2  fv800097.awdV80010
# 3  fv800097.awdV80010
# 4  fv800097.awdV80010
#              FileName      TierType    TierName Label    Start      End  \
# 2391556  fv800096.awd  IntervalTier  V80010_SEG     s  117.060  117.200
# 2391557  fv800096.awd  IntervalTier  V80010_SEG     i  117.200  117.280
# 2391558  fv800096.awd  IntervalTier  V80010_SEG     p  117.280  117.340
# 2391559  fv800096.awd  IntervalTier  V80010_SEG     @  117.340  117.444
# 2391560  fv800096.awd  IntervalTier  V80010_SEG        117.444  117.880
#
#          Duration        FileNameTierName
# 2391556     0.140  fv800096.awdV80010_SEG
# 2391557     0.080  fv800096.awdV80010_SEG
# 2391558     0.060  fv800096.awdV80010_SEG
# 2391559     0.104  fv800096.awdV80010_SEG
# 2391560     0.436  fv800096.awdV80010_SEG

# %%
# extract relevant tiernames
fileTierNames = df.FileNameTierName.drop_duplicates().to_list()
fileTierNames = [fileTier for fileTier in fileTierNames if "_" not in fileTier]
fileTierNames[:10]
# Out:
# ['fv800097.awdV80010',
#  'fv800098.awdV80010',
#  'fv800101.awdV80011',
#  'fv800102.awdV80011',
#  'fv800103.awdV80011',
#  'fv800104.awdV80011',
#  'fv800105.awdV80011',
#  'fv800106.awdV80011',
#  'fv800107.awdV80011',
#  'fv800108.awdV80011']

# %%
# set up list to store results and index to iterate through labels
data = []

# for each tier
for fileTier in fileTierNames:
    labelIndex = 1
    dfLabel = df.loc[df.FileNameTierName==fileTier,]
    dfFon = df.loc[df.FileNameTierName==fileTier+'_FON',]
    dfSeg = df.loc[df.FileNameTierName==fileTier+'_SEG',]
    
    # align segments to labels 
    for index, row in dfSeg.iterrows():
    
        # extract segment with start and end value
        Seg = row['Label']
        start = row['Start']
        end = row['End']
    
        # extract corresponding label (=word)
        label = dfLabel.iloc[labelIndex, dfLabel.columns.get_loc('Label')]
        trans = dfFon.iloc[labelIndex, dfFon.columns.get_loc('Label')]
        labelStart = dfLabel.iloc[labelIndex, dfLabel.columns.get_loc('Start')]
        labelEnd = dfLabel.iloc[labelIndex, dfLabel.columns.get_loc('End')]
        ID = str(labelIndex) + '-' + label
    
        # append everything to list
        data.append([fileTier, ID, label, labelStart, labelEnd, trans, Seg, start, end])
    
        # check if segment matches last segment of label or
        # is smaller (CGN does not perfectly align word boundaries with phone boundaries)
        if labelEnd <= end:
            labelIndex += 1
    
results = pd.DataFrame(data, columns =['FileNameTierName', 'ID', 'WordOrtho', 'WordStart', 'WordEnd', 'WordPhono', 'Phone', 
                    'PhoneStart', 'PhoneEnd',])
results[:20]
# Out:
#       FileNameTierName          ID WordOrtho  WordStart  WordEnd WordPhono  \
# 0   fv800097.awdV80010   1-Falcone   Falcone      0.803    1.434  fAlkowne
# 1   fv800097.awdV80010   1-Falcone   Falcone      0.803    1.434  fAlkowne
# 2   fv800097.awdV80010   1-Falcone   Falcone      0.803    1.434  fAlkowne
# 3   fv800097.awdV80010   1-Falcone   Falcone      0.803    1.434  fAlkowne
# 4   fv800097.awdV80010   1-Falcone   Falcone      0.803    1.434  fAlkowne
# 5   fv800097.awdV80010   1-Falcone   Falcone      0.803    1.434  fAlkowne
# 6   fv800097.awdV80010   1-Falcone   Falcone      0.803    1.434  fAlkowne
# 7   fv800097.awdV80010   1-Falcone   Falcone      0.803    1.434  fAlkowne
# 8   fv800097.awdV80010   1-Falcone   Falcone      0.803    1.434  fAlkowne
# 9   fv800097.awdV80010       2-was       was      1.434    1.631       wAs
# 10  fv800097.awdV80010       2-was       was      1.434    1.631       wAs
# 11  fv800097.awdV80010       2-was       was      1.434    1.631       wAs
# 12  fv800097.awdV80010      3-toen      toen      1.631    1.825      tun=
# 13  fv800097.awdV80010      3-toen      toen      1.631    1.825      tun=
# 14  fv800097.awdV80010      3-toen      toen      1.631    1.825      tun=
# 15  fv800097.awdV80010       4-nog       nog      1.825    2.007      =nOx
# 16  fv800097.awdV80010       4-nog       nog      1.825    2.007      =nOx
# 17  fv800097.awdV80010       5-een       een      2.007    2.121        @n
# 18  fv800097.awdV80010       5-een       een      2.007    2.121        @n
# 19  fv800097.awdV80010  6-onbekend  onbekend      2.121    2.717  Onb@kEnt
#
#    Phone  PhoneStart  PhoneEnd
# 0              0.000     0.803
# 1      f       0.803     0.880
# 2      A       0.880     0.940
# 3      l       0.940     1.010
# 4      k       1.010     1.080
# 5      o       1.080     1.210
# 6      w       1.210     1.240
# 7      n       1.240     1.280
# 8      e       1.280     1.434
# 9      w       1.434     1.480
# 10     A       1.480     1.530
# 11     s       1.530     1.631
# 12     t       1.631     1.700
# 13     u       1.700     1.770
# 14     n       1.770     1.860
# 15     O       1.860     1.940
# 16     x       1.940     2.007
# 17     @       2.007     2.060
# 18     n       2.060     2.121
# 19     O       2.121     2.250

# %%
results.loc[results.WordOrtho=='boodschappenlijstje', ]
# Out:
#            FileNameTierName                       ID            WordOrtho  \
# 1165898  fv801246.awdV80125  175-boodschappenlijstje  boodschappenlijstje
# 1165899  fv801246.awdV80125  175-boodschappenlijstje  boodschappenlijstje
# 1165900  fv801246.awdV80125  175-boodschappenlijstje  boodschappenlijstje
# 1165901  fv801246.awdV80125  175-boodschappenlijstje  boodschappenlijstje
# 1165902  fv801246.awdV80125  175-boodschappenlijstje  boodschappenlijstje
# 1165903  fv801246.awdV80125  175-boodschappenlijstje  boodschappenlijstje
# 1165904  fv801246.awdV80125  175-boodschappenlijstje  boodschappenlijstje
# 1165905  fv801246.awdV80125  175-boodschappenlijstje  boodschappenlijstje
# 1165906  fv801246.awdV80125  175-boodschappenlijstje  boodschappenlijstje
# 1165907  fv801246.awdV80125  175-boodschappenlijstje  boodschappenlijstje
# 1165908  fv801246.awdV80125  175-boodschappenlijstje  boodschappenlijstje
# 1165909  fv801246.awdV80125  175-boodschappenlijstje  boodschappenlijstje
# 1165910  fv801246.awdV80125  175-boodschappenlijstje  boodschappenlijstje
# 1165911  fv801246.awdV80125  175-boodschappenlijstje  boodschappenlijstje
#
#          WordStart  WordEnd        WordPhono Phone  PhoneStart  PhoneEnd
# 1165898     58.618   59.515  botsxAp@lE+stS@     b      58.618    58.680
# 1165899     58.618   59.515  botsxAp@lE+stS@     o      58.680    58.760
# 1165900     58.618   59.515  botsxAp@lE+stS@     t      58.760    58.800
# 1165901     58.618   59.515  botsxAp@lE+stS@     s      58.800    58.860
# 1165902     58.618   59.515  botsxAp@lE+stS@     x      58.860    58.920
# 1165903     58.618   59.515  botsxAp@lE+stS@     A      58.920    58.970
# 1165904     58.618   59.515  botsxAp@lE+stS@     p      58.970    59.090
# 1165905     58.618   59.515  botsxAp@lE+stS@     @      59.090    59.120
# 1165906     58.618   59.515  botsxAp@lE+stS@     l      59.120    59.190
# 1165907     58.618   59.515  botsxAp@lE+stS@    E+      59.190    59.310
# 1165908     58.618   59.515  botsxAp@lE+stS@     s      59.310    59.380
# 1165909     58.618   59.515  botsxAp@lE+stS@     t      59.380    59.420
# 1165910     58.618   59.515  botsxAp@lE+stS@     S      59.420    59.470
# 1165911     58.618   59.515  botsxAp@lE+stS@     @      59.470    59.515

# %%
results.to_pickle(outputPath)

# %% [markdown]
# Load results into environment with:
#
# `results = pd.read_pickle('../DataProcessed/cgn_alignments_dataframe.pkl')`
